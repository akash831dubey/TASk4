# %%
import cv2
import numpy

# %%
image=numpy.ones((500,600,3))

# %%
image=cv2.rectangle(image,(0,0),(600,500),(0,180,255),-1)

# %%
image.shape
# Out:
# (500, 600, 3)

# %%
image=cv2.line(image,(100,50),(300,50),(0,0,255),6)

# %%
image=cv2.line(image,(300,50),(300,250),(0,0,255),6)

# %%
image=cv2.line(image,(300,250),(480,250),(0,0,255),6)

# %%
image=cv2.line(image,(480,50),(480,150),(0,0,25),6)

# %%
image=cv2.line(image,(100,150),(480,150),(0,0,255),6)

# %%
image=cv2.line(image,(100,150),(100,250),(0,0,255),6)

# %%
cv2.circle(image,(200,195),8, (0,0,255), -1)
# Out:
# array([[[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        ...,
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
# ...

# %%
cv2.circle(image,(200,95),8, (0,0,255), -1)
# Out:
# array([[[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        ...,
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
# ...

# %%
cv2.circle(image,(380,195),8, (0,0,255), -1)
# Out:
# array([[[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        ...,
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
# ...

# %%
cv2.circle(image,(380,95),8, (0,0,255), -1)
# Out:
# array([[[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        ...,
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.]],
#
#        [[  0., 180., 255.],
#         [  0., 180., 255.],
#         [  0., 180., 255.],
#         ...,
#         [  0., 180., 255.],
#         [  0., 180., 255.],
# ...

# %%
cv2.imshow("TASK4.1",image)
cv2.waitKey()
cv2.destroyAllWindows()
